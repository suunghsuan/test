# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
tdata=pd.read_csv("cases_add_Taiwan .csv",encoding='big5')
tdata[['Date','Worldwide']].plot(kind='line',x='Date',y='Worldwide',title="covid-19 daily reports")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
tdata=pd.read_csv("cases_add_Taiwan .csv",encoding='big5')
data_pivot=tdata.pivot_table(index='Date',values=['Argentina','Algeria','Australia'])
data_pivot.plot(title='life expection in north asia',legend=False)
plt.show()
